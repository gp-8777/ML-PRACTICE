# %% [markdown]
# <a href="https://colab.research.google.com/github/gp-8777/ML-PRACTICE/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Python program

name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Hello,", name)
print("You are", age, "years old.")

if age >= 18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# Enter your name: Gaurav
# Enter your age: 21
# Hello, Gaurav
# You are 21 years old.
# You are an adult.

# %%
# Calculate the sum of two numbers

num1 = 10
num2 = 20

sum = num1 + num2

print("First number:", num1)
print("Second number:", num2)
print("Sum:", sum)
# Out:
# First number: 10
# Second number: 20
# Sum: 30

# %%
# Simple Machine Learning Example
# Predict Pass/Fail based on study hours

from sklearn.linear_model import LogisticRegression

# Training data
# Hours studied
X = [[1], [2], [3], [4], [5], [6], [7], [8]]

# 0 = Fail, 1 = Pass
y = [0, 0, 0, 0, 1, 1, 1, 1]

# Create the model
model = LogisticRegression()

# Train the model
model.fit(X, y)

# Make a prediction
hours = [[5]]

prediction = model.predict(hours)

if prediction[0] == 1:
    print("Student will Pass")
else:
    print("Student will Fail")
# Out:
# Student will Pass
